# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.3433, 0.3607, 0.6806],
#         [0.7073, 0.2794, 0.1985],
#         [0.5152, 0.7234, 0.0934],
#         [0.8269, 0.0607, 0.2919],
#         [0.7000, 0.7838, 0.5337]])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'
